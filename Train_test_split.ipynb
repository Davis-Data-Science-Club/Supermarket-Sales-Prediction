# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv("complete_regression.csv")
df
# Out:
#       product_id product_type       product_name size  colour  price  \
# 0              1        Shirt       Oxford Cloth    S     red    114
# 1            148        Shirt              Linen    L  orange    116
# 2            475       Jacket             Puffer   XS    blue    110
# 3            635       Jacket              Coach   XS  orange    115
# 4            639       Jacket              Coach   XL  orange    115
# ...          ...          ...                ...  ...     ...    ...
# 4995        1192     Trousers            Pleated    M     red     90
# 4996        1060     Trousers            Joggers   XS  yellow     94
# 4997        1065     Trousers            Joggers   XS   green     94
# 4998        1091     Trousers            Cropped    S  orange     99
# 4999        1250     Trousers  Tracksuit Bottoms   XS  indigo     91
#
#       quantity_x                                        description  sales_id  \
# 0             53        A red coloured, S sized, Oxford Cloth Shirt        22
# 1             73            A orange coloured, L sized, Linen Shirt        20
# 2             57           A blue coloured, XS sized, Puffer Jacket        21
# 3             42          A orange coloured, XS sized, Coach Jacket        25
# 4             46          A orange coloured, XL sized, Coach Jacket        26
# ...          ...                                                ...       ...
# 4995          40          A red coloured, M sized, Pleated Trousers       275
# 4996          62      A yellow coloured, XS sized, Joggers Trousers      4576
# 4997          77       A green coloured, XS sized, Joggers Trousers      2390
# 4998          78       A orange coloured, S sized, Cropped Trousers      2755
# 4999          63  A indigo coloured, XS sized, Tracksuit Bottoms...       693
#
#       order_id  ...  order_date  delivery_date         customer_name  \
# 0            5  ...   2021-3-23     2021-03-24   Artemas Vasilischev
# 1            5  ...   2021-3-23     2021-03-24   Artemas Vasilischev
# 2            5  ...   2021-3-23     2021-03-24   Artemas Vasilischev
# 3            5  ...   2021-3-23     2021-03-24   Artemas Vasilischev
# 4            5  ...   2021-3-23     2021-03-24   Artemas Vasilischev
# ...        ...  ...         ...            ...                   ...
# 4995        62  ...   2021-7-30     2021-08-13             Law Foker
# 4996       912  ...   2021-8-23     2021-09-09         Cinda Alleyne
# 4997       485  ...    2021-1-8     2021-01-28       Ginnie Glasheen
# 4998       551  ...   2021-9-16     2021-09-18      Barclay Kinsella
# 4999       147  ...   2021-9-28     2021-10-16  Nathaniel McCandless
#
#            gender  age                  home_address zip_code  \
# 0        Bigender   53  33 Richards JunctionApt. 478     7650
# 1        Bigender   53  33 Richards JunctionApt. 478     7650
# 2        Bigender   53  33 Richards JunctionApt. 478     7650
# 3        Bigender   53  33 Richards JunctionApt. 478     7650
# 4        Bigender   53  33 Richards JunctionApt. 478     7650
# ...           ...  ...                           ...      ...
# 4995  Genderfluid   66    4715 Hand View RdSuite 955     4739
# 4996  Genderfluid   55      60 Claudia LaneSuite 183     1702
# 4997   Polygender   77     08 Howe BoulevardApt. 286     9561
# 4998         Male   47       698 Doyle RoadSuite 219     6913
# 4999   Polygender   59   5085 Bergstrom MewsApt. 347     3302
#
#                  city              state    country
# 0     South Rileyview  Western Australia  Australia
# 1     South Rileyview  Western Australia  Australia
# 2     South Rileyview  Western Australia  Australia
# 3     South Rileyview  Western Australia  Australia
# 4     South Rileyview  Western Australia  Australia
# ...               ...                ...        ...
# 4995         Colestad         Queensland  Australia
# 4996      Caitlinview           Victoria  Australia
# 4997      West Stella    South Australia  Australia
# 4998      Lincolnbury           Victoria  Australia
# 4999    West Eviebury  Western Australia  Australia
#
# [5000 rows x 25 columns]

# %%
# Most optimal ratio is usually 80:20

train, test = train_test_split(df, test_size = 0.20)

# if we our predictor variable is state (for example)
predictor_var = "state"
X = df.drop([predictor_var], axis = 1)
y = df[predictor_var]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
X_train
# Out:
#       product_id product_type     product_name size  colour  price  \
# 1846         388        Shirt  Casual Slim Fit    L     red    113
# 4080         702       Jacket      Trench Coat    M     red    112
# 2363        1089     Trousers          Cropped   XL     red     99
# 3629         161        Shirt            Linen    S    blue    116
# 936          765       Jacket          Peacoat   XS  violet    102
# ...          ...          ...              ...  ...     ...    ...
# 4299        1188     Trousers     High-Waisted    L  violet     98
# 171         1190     Trousers          Pleated   XS     red     90
# 461          488       Jacket           Puffer    L  violet    110
# 4119         929     Trousers       Drawstring   XL   green    104
# 2671         988     Trousers             Wool    L  orange    111
#
#       quantity_x                                        description  sales_id  \
# 1846          78     A red coloured, L sized, Casual Slim Fit Shirt      3311
# 4080          57        A red coloured, M sized, Trench Coat Jacket      3243
# 2363          78         A red coloured, XL sized, Cropped Trousers       223
# 3629          77              A blue coloured, S sized, Linen Shirt      3836
# 936           54        A violet coloured, XS sized, Peacoat Jacket       540
# ...          ...                                                ...       ...
# 4299          68  A violet coloured, L sized, High-Waisted Trousers       718
# 171           42         A red coloured, XS sized, Pleated Trousers      1326
# 461           49          A violet coloured, L sized, Puffer Jacket      4094
# 4119          49    A green coloured, XL sized, Drawstring Trousers       477
# 2671          56          A orange coloured, L sized, Wool Trousers      2332
#
#       order_id  ...  payment  order_date  delivery_date         customer_name  \
# 1846       668  ...    40483   2021-3-15     2021-03-30       Blayne Sabatier
# 4080       653  ...    19186   2021-2-19     2021-03-18      Sigismundo Basek
# 2363        47  ...    35453   2021-4-21     2021-04-23        Jojo Toffanini
# 3629       766  ...    13750    2021-8-6     2021-08-15         Reba Crauford
# 936        117  ...    58134    2021-1-8     2021-01-23  Constance Piddington
# ...        ...  ...      ...         ...            ...                   ...
# 4299       152  ...    24866    2021-3-9     2021-03-12          Dani Pinches
# 171        275  ...    17666    2021-1-5     2021-01-15          Valery Pache
# 461        814  ...    47232    2021-3-4     2021-03-28         Dannie Fidler
# 4119       105  ...    46013   2021-6-25     2021-07-14     Joelynn Remington
# 2671       474  ...    17401   2021-8-19     2021-09-09        Kristofor Roos
#
#            gender age                   home_address zip_code  \
# 1846   Non-binary  20     292 Casper IslandSuite 778     6624
# 4080         Male  53     4355 Caitlin CourtApt. 697     6606
# 2363      Agender  34          3285 Kai MewsApt. 727     8839
# 3629  Genderfluid  68         394 Lily HillSuite 153     2353
# 936   Genderfluid  27           135 Ella RunApt. 424     4268
# ...           ...  ..                            ...      ...
# 4299   Polygender  43    83 Reynolds ParadeSuite 974      299
# 171    Polygender  53  3203 Jackson TerraceSuite 580     5466
# 461   Genderfluid  32         157 Rohan MallApt. 466     4145
# 4119      Agender  33       94 Archie CourtSuite 659     2010
# 2671      Agender  22       5567 Clarke MallApt. 756     4043
#
#                    city    country
# 1846            Maxberg  Australia
# 4080          Amberland  Australia
# 2363        Elijahshire  Australia
# 3629         Beahanfurt  Australia
# 936     East Chasehaven  Australia
# ...                 ...        ...
# 4299          Howehaven  Australia
# 171   South Claudialand  Australia
# 461            East Max  Australia
# 4119       West Lachlan  Australia
# 2671         Jordanside  Australia
#
# [4000 rows x 24 columns]
