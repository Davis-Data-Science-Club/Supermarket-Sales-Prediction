# %%
import pandas as pd
df = pd.read_csv('/Users/nirmalkaluvai/Downloads/orders.csv')
df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
max_val= df["payment"].quantile(.95)
max_val
# Out:
# 57008.299999999996

# %%
df[df['payment']>max_val]
# Out:
#      order_id  customer_id  payment  order_date delivery_date
# 12         13          204    57810  2021-10-15    2021-10-31
# 28         29          993    57645   2021-3-22    2021-03-28
# 29         30          260    59350    2021-7-7    2021-07-26
# 77         78          681    58179   2021-5-13    2021-05-29
# 79         80          872    59554   2021-4-26    2021-05-20
# 99        100          817    57063   2021-3-30    2021-04-16
# 106       107          127    58760   2021-1-11    2021-02-03
# 116       117          971    58134    2021-1-8    2021-01-23
# 136       137          298    58875  2021-10-18    2021-10-20
# 174       175          309    57197   2021-3-22    2021-04-16
# 198       199          206    58054   2021-5-17    2021-05-18
# 206       207          644    57755   2021-9-25    2021-09-28
# 230       231          731    58824   2021-3-20    2021-04-09
# 237       238          328    59828   2021-3-17    2021-03-27
# ...

# %%
min_val = df["payment"].quantile(.05)
df[df['payment']<min_val]
# Out:
#      order_id  customer_id  payment  order_date delivery_date
# 20         21          124    11261    2021-4-4    2021-04-17
# 52         53          528    10517   2021-4-22    2021-05-02
# 69         70          802    11279   2021-5-15    2021-05-26
# 87         88          567    10904   2021-7-19    2021-08-15
# 89         90          809    11475   2021-6-13    2021-07-07
# 103       104          366    11454    2021-6-5    2021-06-23
# 131       132          562    10396   2021-4-17    2021-05-01
# 138       139          871    11224   2021-6-15    2021-06-28
# 154       155          834    11166   2021-6-30    2021-07-18
# 162       163           84    11473   2021-6-12    2021-06-17
# 165       166          113    11914   2021-7-11    2021-07-14
# 176       177          315    11314   2021-8-20    2021-09-01
# 227       228          773    10857    2021-1-6    2021-01-17
# 251       252          683    11465   2021-1-11    2021-02-05
# ...

# %%
clean_data= df[(df['payment']<max_val) & (df['payment']>min_val)]
clean_data
# Out:
#      order_id  customer_id  payment order_date delivery_date
# 0           1           64    30811  2021-8-30    2021-09-24
# 1           2          473    50490   2021-2-3    2021-02-13
# 2           3          774    46763  2021-10-8    2021-11-03
# 3           4          433    39782   2021-5-6    2021-05-19
# 4           5          441    14719  2021-3-23    2021-03-24
# ..        ...          ...      ...        ...           ...
# 995       996          345    37843  2021-1-13    2021-02-02
# 996       997          346    53831  2021-1-18    2021-01-31
# 997       998          407    53308   2021-5-5    2021-05-21
# 998       999          428    31643  2021-6-15    2021-07-12
# 999      1000          896    27836   2021-4-7    2021-04-24
#
# [900 rows x 5 columns]

# %%
clean_data.head()
clean_data.describe()
# Out:
#           order_id  customer_id       payment
# count   900.000000   900.000000    900.000000
# mean    502.097778   506.187778  33888.556667
# std     288.088077   275.913246  13017.394050
# min       1.000000     1.000000  12033.000000
# 25%     254.500000   282.000000  22748.500000
# 50%     505.500000   509.000000  33697.500000
# 75%     755.250000   736.000000  44825.250000
# max    1000.000000  1000.000000  57006.000000
